# %%
import pandas as pd

# %%
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'hd']
data = pd.read_csv('processed.cleveland.data', names=names)

# %% [markdown]
# ## Removing missing values

# %%
data = data[~data['ca'].isin(['?'])]
data = data[~data['thal'].isin(['?'])]
data = data.reset_index()
data.drop(columns=['index'])
data.drop(0, axis=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 1     63    1   1       145   233    1        2      150      0      2.3
# 2     67    1   4       160   286    0        2      108      1      1.5
# 3     67    1   4       120   229    0        2      129      1      2.6
# 4     37    1   3       130   250    0        0      187      0      3.5
# 5     41    0   2       130   204    0        2      172      0      1.4
# 6     56    1   2       120   236    0        0      178      0      0.8
# 7     62    0   4       140   268    0        2      160      0      3.6
# 8     57    0   4       120   354    0        0      163      1      0.6
# 9     63    1   4       130   254    0        2      147      0      1.4
# 10    53    1   4       140   203    1        2      155      1      3.1
# 11    57    1   4       140   192    0        0      148      0      0.4
# ...

# %% [markdown]
# ### Binning the data

# %%
data['age'], bins = pd.qcut(data['age'], retbins= True, q=5, labels=False)
print(bins)
# Out:
# [29. 45. 53. 58. 62. 77.]

# %%
data['trestbps'], bins = pd.qcut(data['trestbps'], retbins=True, q=5, labels=False)
print(bins)
# Out:
# [ 94.  120.  126.  134.  144.6 200. ]

# %%
data['chol'], bins = pd.qcut(data['chol'], retbins=True, q=5, labels=False)
print(bins)
# Out:
# [126. 204. 230. 254. 286. 564.]

# %%
data['thalach'], bins = pd.qcut(data['thalach'], retbins=True, q=5, labels=False)
print(bins)
# Out:
# [ 71. 130. 146. 159. 170. 202.]

# %%
data['oldpeak'], bins = pd.qcut(data['oldpeak'], retbins=True, q=3, labels=False)
print(bins)
# Out:
# [0.  0.1 1.4 6.2]

# %%
data = data[~data['ca'].isin(['?'])]
data = data[~data['thal'].isin(['?'])]
data = data.reset_index()

# %% [markdown]
# ### Obtain amount of data points in class of each variable

# %%
data['age'].value_counts()
# Out:
# 2    70
# 1    61
# 0    61
# 4    60
# 3    45
# Name: age, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# 1.0    201
# 0.0     96
# Name: sex, dtype: int64

# %%
data['cp'].value_counts()
# Out:
# 4.0    142
# 3.0     83
# 2.0     49
# 1.0     23
# Name: cp, dtype: int64

# %%
data['fbs'].value_counts()
# Out:
# 0.0    254
# 1.0     43
# Name: fbs, dtype: int64

# %%
data['restecg'].value_counts()
# Out:
# 0.0    147
# 2.0    146
# 1.0      4
# Name: restecg, dtype: int64

# %%
data['exang'].value_counts()
# Out:
# 0.0    200
# 1.0     97
# Name: exang, dtype: int64

# %%
data['slope'].value_counts()
# Out:
# 1.0    139
# 2.0    137
# 3.0     21
# Name: slope, dtype: int64

# %%
data['thal'].value_counts()
# Out:
# 3.0    164
# 7.0    115
# 6.0     18
# Name: thal, dtype: int64

# %%
data['hd'].value_counts()
# Out:
# 0    160
# 1     54
# 3     35
# 2     35
# 4     13
# Name: hd, dtype: int64

# %%
data['trestbps'].value_counts()
# Out:
# 0    97
# 4    61
# 2    59
# 3    56
# 1    24
# Name: trestbps, dtype: int64

# %%
data['chol'].value_counts()
# Out:
# 2    61
# 4    60
# 0    60
# 3    59
# 1    57
# Name: chol, dtype: int64

# %%
data['thalach'].value_counts()
# Out:
# 0    62
# 3    61
# 2    61
# 1    57
# 4    56
# Name: thalach, dtype: int64

# %%
data['oldpeak'].value_counts()
# Out:
# 1    105
# 0    102
# 2     90
# Name: oldpeak, dtype: int64

# %%
data.to_csv('discretized_cleveland.csv')
